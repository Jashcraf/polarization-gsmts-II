# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
pth = "C:/Users/UASAL-OPTICS/Downloads/TWA7_IBand.fits"
twa7 = fits.getdata(pth)

# %%
twa7.shape
# Out:
# (8, 1, 1, 2048, 2048)

# %%
twa7_hdr = fits.open(pth)
twa7_hdr[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    5 / number of data axes
# NAXIS1  =                 2048 / length of data axis 1
# NAXIS2  =                 2048 / length of data axis 2
# NAXIS3  =                    1 / length of data axis 3
# NAXIS4  =                    1 / length of data axis 4
# NAXIS5  =                    8 / length of data axis 5
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# WAVE    =                0.806 / wavelength [microns]
# CTYPE1  = 'RA---TAN'
# CRVAL1  =                   0. / RAD
# CRPIX1  =                 1025
# CDELT1  =         -4.16666E-07 / pixel scale x [deg]
# CUNIT1  = 'deg     '
# CTYPE2  = 'DEC--TAN'
# ...

# %% [markdown]
# There is a bright pixel right in the center of this file, so it

# %%
from matplotlib.colors import LogNorm
plt.imshow(np.log10(twa7[0,0,0]),vmin=-28,vmax=-27)
plt.colorbar()
# Out:
# C:\Users\UASAL-OPTICS\AppData\Local\Temp\ipykernel_28428\3391513667.py:2: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(twa7[0,0,0]),vmin=-28,vmax=-27)
